# %% [markdown]
# #### 1. Installing the required python packages

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (22.3.1)

# %%
# !pip install -r requirements38.txt
# Out:
# Collecting absl-py==0.7.1
#   Downloading absl-py-0.7.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 1.1 MB/s eta 0:00:00
# done
# Collecting astor==0.8.0
#   Downloading astor-0.8.0-py2.py3-none-any.whl (27 kB)
# Collecting boto==2.49.0
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.8 MB/s eta 0:00:00
# Collecting boto3==1.9.188
#   Downloading boto3-1.9.188-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 17.3 MB/s eta 0:00:00
# Collecting botocore==1.12.188
#   Downloading botocore-1.12.188-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 36.4 MB/s eta 0:00:00
# Collecting certifi==2019.6.16
#   Downloading certifi-2019.6.16-py2.py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 kB 18.4 MB/s eta 0:00:00
# Collecting chardet==3.0.4
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.7 MB/s eta 0:00:00
# Collecting cloudpickle==1.6.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting docutils==0.14
#   Downloading docutils-0.14-py3-none-any.whl (543 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 45.5 MB/s eta 0:00:00
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# done
# Collecting gdown==4.3.0
#   Downloading gdown-4.3.0.tar.gz (13 kB)
# done
# done
# done
# Collecting gensim==3.8.0
#   Downloading gensim-3.8.0.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 37.0 MB/s eta 0:00:00
# done
# Collecting google-pasta==0.1.7
#   Downloading google_pasta-0.1.7-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 6.8 MB/s eta 0:00:00
# Collecting idna==2.8
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 5.5 MB/s eta 0:00:00
# Collecting jmespath==0.9.4
#   Downloading jmespath-0.9.4-py2.py3-none-any.whl (24 kB)
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.0/303.0 kB 34.0 MB/s eta 0:00:00
# Collecting jupyter==1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting Keras-Applications==1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.7 MB/s eta 0:00:00
# Collecting Keras-Preprocessing==1.1.0
#   Downloading Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 5.3 MB/s eta 0:00:00
# Collecting loky==2.9.0
#   Downloading loky-2.9.0-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.2 MB/s eta 0:00:00
# Collecting line_profiler==3.3.1
#   Downloading line_profiler-3.3.1-cp39-cp39-manylinux2010_x86_64.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 275.5 kB/s eta 0:00:00
# Collecting Markdown==3.1.1
#   Downloading Markdown-3.1.1-py2.py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 3.2 MB/s eta 0:00:00
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.1 MB/s eta 0:00:00
# done
# Collecting matplotlib==2.2.5
#   Downloading matplotlib-2.2.5.tar.gz (36.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 25.6 MB/s eta 0:00:00
# done
# Collecting numpy==1.21.5
#   Downloading numpy-1.21.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 37.1 MB/s eta 0:00:00
# Collecting pandas==1.2.0
#   Downloading pandas-1.2.0-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 47.2 MB/s eta 0:00:00
# Collecting pre-commit==2.8.2
#   Downloading pre_commit-2.8.2-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 20.3 MB/s eta 0:00:00
# Collecting protobuf==3.9.0
#   Downloading protobuf-3.9.0-py2.py3-none-any.whl (432 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.4/432.4 kB 20.6 MB/s eta 0:00:00
# Collecting pyfunctional==1.4.2
#   Downloading PyFunctional-1.4.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.3 MB/s eta 0:00:00
# Collecting python-dateutil==2.8.0
#   Downloading python_dateutil-2.8.0-py2.py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 21.3 MB/s eta 0:00:00
# Collecting pytz==2019.1
#   Downloading pytz-2019.1-py2.py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.9/510.9 kB 44.8 MB/s eta 0:00:00
# Collecting requests==2.22.0
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 7.1 MB/s eta 0:00:00
# Collecting s3transfer==0.2.1
#   Downloading s3transfer-0.2.1-py2.py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 8.2 MB/s eta 0:00:00
# Collecting scikit-learn==0.24
#   Downloading scikit_learn-0.24.0-cp39-cp39-manylinux2010_x86_64.whl (23.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 39.6 MB/s eta 0:00:00
# Collecting six==1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting smart-open==1.8.4
#   Downloading smart_open-1.8.4.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 8.2 MB/s eta 0:00:00
# done
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp39-cp39-manylinux1_x86_64.whl (25.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 34.8 MB/s eta 0:00:00
# Collecting setuptools~=47.1.0
#   Downloading setuptools-47.1.1-py3-none-any.whl (583 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.2/583.2 kB 47.3 MB/s eta 0:00:00
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# done
# Collecting tqdm==4.51.0
#   Downloading tqdm-4.51.0-py2.py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# thon3/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements38.txt (line 19)) (0.8.4)
# Requirement already satisfied: pyzmq>=17 in /databricks/python3/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (22.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /databricks/python3/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (0.9.4)
# Requirement already satisfied: argon2-cffi in /databricks/python3/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (20.1.0)
# Requirement already satisfied: prometheus-client in /databricks/python3/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /databricks/python3/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (1.8.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 10.9 MB/s eta 0:00:00
# Collecting requests[socks]
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.4 MB/s eta 0:00:00
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.3 MB/s eta 0:00:00
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 8.1 MB/s eta 0:00:00
#   Downloading requests-2.27.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 8.2 MB/s eta 0:00:00
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 8.5 MB/s eta 0:00:00
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 8.3 MB/s eta 0:00:00
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 7.6 MB/s eta 0:00:00
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.9 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /databricks/python3/lib/python3.9/site-packages (from jedi>=0.16->IPython>=0.13->line_profiler==3.3.1->-r requirements38.txt (line 23)) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert->jupyter==1.0.0->-r requirements38.txt (line 19)) (2.0.1)
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.4.7-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 17.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.6-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 16.7 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.5-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 14.7 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.4-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 15.4 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.3-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 13.8 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.2-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 17.4 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 16.4 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 16.3 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.5-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 17.5 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.4-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 1.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.3-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 17.5 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.2-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 16.1 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 17.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 17.5 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.2-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 17.1 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.4/130.4 kB 16.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 15.5 MB/s eta 0:00:00
# Collecting jupyter-core
#   Downloading jupyter_core-5.1.2-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 11.2 MB/s eta 0:00:00
# Collecting traitlets>=4.2
#   Downloading traitlets-5.8.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: async-generator in /databricks/python3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter==1.0.0->-r requirements38.txt (line 19)) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /databricks/python3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements38.txt (line 19)) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.9/site-packages (from pexpect>4.3->IPython>=0.13->line_profiler==3.3.1->-r requirements38.txt (line 23)) (0.7.0)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=0.13->line_profiler==3.3.1->-r requirements38.txt (line 23)) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /databricks/python3/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (1.14.6)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0->-r requirements38.txt (line 19)) (0.5.1)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter==1.0.0->-r requirements38.txt (line 19)) (2.20)
# Requirement already satisfied: pyrsistent>=0.14.0 in /databricks/python3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements38.txt (line 19)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements38.txt (line 19)) (21.2.0)
# Building wheels for collected packages: absl-py, gast, gdown, gensim, nltk, matplotlib, smart-open, termcolor, wrapt
# done
#   Created wheel for absl-py: filename=absl_py-0.7.1-py3-none-any.whl size=117858 sha256=a3b8b9aea2ea44c855babf2ea6178ca693056aa8ff40e8038ab1e6ff4bdd14c9
#   Stored in directory: /root/.cache/pip/wheels/79/f3/af/7d0cde3ccba234268804d87c7fac1b3facee083fc47ed6b35a
# done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=9a3f28eb0d46410f64e8e9eee5bda00009ebd0785e51344189062623e7953f63
#   Stored in directory: /root/.cache/pip/wheels/bd/1a/71/ef38c2b6346350d877f1f56383271151877adaaf4afe9423d5
# done
#   Created wheel for gdown: filename=gdown-4.3.0-py3-none-any.whl size=14412 sha256=df79776db63913b0f0ee5ccd556b5ac923baf473631c527d7d653b45ca50282d
#   Stored in directory: /root/.cache/pip/wheels/f7/a3/ab/115ed848aa6792d2cc96916419a6f4c2de28ea943e3f0197b6
# done
#   Created wheel for gensim: filename=gensim-3.8.0-cp39-cp39-linux_x86_64.whl size=24952757 sha256=752d61e5cf52fbfac12abd742f81c07e46becdc1fc8d03226ccc934e4e9b19b3
#   Stored in directory: /root/.cache/pip/wheels/43/a9/56/a1e12d0655384810fef36ef3a45812bdf7d6a9efc51a91b350
# done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434690 sha256=52c3768e6d9ce2cf25d9a1cdf3882191ae27bb98714883b00395a3737969c809
#   Stored in directory: /root/.cache/pip/wheels/fb/89/3d/bc0e6aab0897911a92067396d96f27f31862809fb21440072a
# done
#   Created wheel for matplotlib: filename=matplotlib-2.2.5-cp39-cp39-linux_x86_64.whl size=11634372 sha256=372ba10320da067bb873c650e36aefffe1738c204168d7061b4e67987b48c60e
#   Stored in directory: /root/.cache/pip/wheels/e4/7a/65/0cfd1eebf5dd5ac90e35cf095981423bda5851fb6f8f8b4b2e
# done
#   Created wheel for smart-open: filename=smart_open-1.8.4-py3-none-any.whl size=68210 sha256=309216cf271e33d09b1574b99aa2709d6f0760307535e6ad53acc5bd1a0a9754
#   Stored in directory: /root/.cache/pip/wheels/8e/7f/e9/c50fd4127e558df75f16df11bd5b9d33530d250ba931735c7b
# done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=de6de7921ba4ae4b9ee4bc7dc11824698214075817f350a3e23cc2a8311118c5
#   Stored in directory: /root/.cache/pip/wheels/6d/00/51/e04e70a050b271a6aac779726204a324ada2b39b99334175c3
# done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp39-cp39-linux_x86_64.whl size=75734 sha256=0b7b2a2d885e24f588feb613de2f114d71288a3efe05e0722b045da365dc04b2
#   Stored in directory: /root/.cache/pip/wheels/fe/3b/09/cb4a9b0ff2f763b629ab60e13b4cf7a00aec0d35523b217baf
# Successfully built absl-py gast gdown gensim nltk matplotlib smart-open termcolor wrapt
# Installing collected packages: wrapt, termcolor, pytz, jmespath, google-pasta, docutils, chardet, certifi, boto, Werkzeug, urllib3, traitlets, tqdm, toml, tabulate, soupsieve, six, setuptools, regex, pyyaml, PySocks, numpy, joblib, idna, identify, gast, dill, cloudpickle, cfgv, astor, scipy, requests, qtpy, python-dateutil, pyfunctional, protobuf, nodeenv, nltk, Markdown, loky, Keras-Preprocessing, jupyter-core, h5py, beautifulsoup4, absl-py, scikit-learn, pre-commit, pandas, matplotlib, Keras-Applications, jupyter-client, botocore, s3transfer, line_profiler, gdown, qtconsole, jupyter-console, boto3, smart-open, gensim, jupyter
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Not uninstalling pytz at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'pytz'. No files were found to uninstall.
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 0.10.0
#     Not uninstalling jmespath at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'jmespath'. No files were found to uninstall.
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Not uninstalling chardet at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'chardet'. No files were found to uninstall.
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Not uninstalling certifi at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'certifi'. No files were found to uninstall.
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.7
#     Not uninstalling urllib3 at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'urllib3'. No files were found to uninstall.
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.0
#     Not uninstalling traitlets at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'traitlets'. No files were found to uninstall.
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Not uninstalling six at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'six'. No files were found to uninstall.
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.0.4
#     Not uninstalling setuptools at /usr/local/lib/python3.9/dist-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'setuptools'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Not uninstalling numpy at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Not uninstalling joblib at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'joblib'. No files were found to uninstall.
#   Attempting uninstall: idna
#     Found existing installation: idna 3.2
#     Not uninstalling idna at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'idna'. No files were found to uninstall.
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Not uninstalling scipy at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Not uninstalling requests at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Not uninstalling python-dateutil at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'python-dateutil'. No files were found to uninstall.
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.5
#     Not uninstalling protobuf at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.8.1
#     Not uninstalling jupyter-core at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'jupyter-core'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Not uninstalling pandas at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Not uninstalling matplotlib at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Not uninstalling jupyter-client at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'jupyter-client'. No files were found to uninstall.
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.24.18
#     Not uninstalling botocore at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'botocore'. No files were found to uninstall.
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.5.2
#     Not uninstalling s3transfer at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 's3transfer'. No files were found to uninstall.
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.21.18
#     Not uninstalling boto3 at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'boto3'. No files were found to uninstall.
# Successfully installed Keras-Applications-1.0.8 Keras-Preprocessing-1.1.0 Markdown-3.1.1 PySocks-1.7.1 Werkzeug-0.15.4 absl-py-0.7.1 astor-0.8.0 beautifulsoup4-4.11.1 boto-2.49.0 boto3-1.9.188 botocore-1.12.188 certifi-2019.6.16 cfgv-3.3.1 chardet-3.0.4 cloudpickle-1.6.0 dill-0.3.6 docutils-0.14 gast-0.2.2 gdown-4.3.0 gensim-3.8.0 google-pasta-0.1.7 h5py-3.7.0 identify-2.5.12 idna-2.8 jmespath-0.9.4 joblib-1.0.0 jupyter-1.0.0 jupyter-client-7.2.0 jupyter-console-6.4.4 jupyter-core-5.1.2 line_profiler-3.3.1 loky-2.9.0 matplotlib-2.2.5 nltk-3.5 nodeenv-1.7.0 numpy-1.21.5 pandas-1.2.0 pre-commit-2.8.2 protobuf-3.9.0 pyfunctional-1.4.2 python-dateutil-2.8.0 pytz-2019.1 pyyaml-6.0 qtconsole-5.4.0 qtpy-2.3.0 regex-2022.10.31 requests-2.22.0 s3transfer-0.2.1 scikit-learn-0.24.0 scipy-1.5.4 setuptools-47.1.1 six-1.12.0 smart-open-1.8.4 soupsieve-2.3.2.post1 tabulate-0.9.0 termcolor-1.1.0 toml-0.10.2 tqdm-4.51.0 traitlets-5.8.0 urllib3-1.25.3 wrapt-1.11.2

# %%
# !pip install azure-storage-file-datalake
# !pip install adlfs
# !pip install fsspec
# Out:
# Collecting azure-storage-file-datalake
#   Downloading azure_storage_file_datalake-12.9.1-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.8/238.8 kB 1.3 MB/s eta 0:00:00
# Collecting azure-storage-blob<13.0.0,>=12.14.1
#   Downloading azure_storage_blob-12.14.1-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 701.9 kB/s eta 0:00:00
# Collecting msrest>=0.7.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 10.8 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.24.2
#   Downloading azure_core-1.26.2-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.8/173.8 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.11.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.2->azure-storage-file-datalake) (1.12.0)
# Requirement already satisfied: requests>=2.18.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.2->azure-storage-file-datalake) (2.22.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: cryptography>=2.1.4 in /databricks/python3/lib/python3.9/site-packages (from azure-storage-blob<13.0.0,>=12.14.1->azure-storage-file-datalake) (3.4.8)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.9 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-file-datalake) (2019.6.16)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.14.1->azure-storage-file-datalake) (1.14.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.2->azure-storage-file-datalake) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.2->azure-storage-file-datalake) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.2->azure-storage-file-datalake) (2.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.14.1->azure-storage-file-datalake) (2.20)
# Installing collected packages: typing-extensions, oauthlib, isodate, requests-oauthlib, azure-core, msrest, azure-storage-blob, azure-storage-file-datalake
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8
#     Can't uninstall 'typing-extensions'. No files were found to uninstall.
# Successfully installed azure-core-1.26.2 azure-storage-blob-12.14.1 azure-storage-file-datalake-12.9.1 isodate-0.6.1 msrest-0.7.1 oauthlib-3.2.2 requests-oauthlib-1.3.1 typing-extensions-4.4.0
# Collecting adlfs
#   Downloading adlfs-2022.11.2-py3-none-any.whl (25 kB)
# Collecting fsspec>=2021.10.1
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 1.7 MB/s eta 0:00:00
# Collecting azure-datalake-store<0.1,>=0.0.46
#   Downloading azure_datalake_store-0.0.52-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: azure-storage-blob>=12.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from adlfs) (12.14.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from adlfs) (1.26.2)
# Collecting aiohttp>=3.7.0
#   Downloading aiohttp-3.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.0 MB/s eta 0:00:00
# Collecting azure-identity
#   Downloading azure_identity-1.12.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.5/135.5 kB 17.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /databricks/python3/lib/python3.9/site-packages (from aiohttp>=3.7.0->adlfs) (2.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 22.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.9/site-packages (from aiohttp>=3.7.0->adlfs) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.1->adlfs) (1.12.0)
# Requirement already satisfied: requests>=2.18.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.1->adlfs) (2.22.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.1->adlfs) (4.4.0)
# Collecting adal>=0.4.2
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: cffi in /databricks/python3/lib/python3.9/site-packages (from azure-datalake-store<0.1,>=0.0.46->adlfs) (1.14.6)
# Requirement already satisfied: msrest>=0.7.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from azure-storage-blob>=12.12.0->adlfs) (0.7.1)
# Requirement already satisfied: cryptography>=2.1.4 in /databricks/python3/lib/python3.9/site-packages (from azure-storage-blob>=12.12.0->adlfs) (3.4.8)
# Collecting msal-extensions<2.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting msal<2.0.0,>=1.12.0
#   Downloading msal-1.20.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from adal>=0.4.2->azure-datalake-store<0.1,>=0.0.46->adlfs) (2.8.0)
# Collecting PyJWT<3,>=1.0.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi->azure-datalake-store<0.1,>=0.0.46->adlfs) (2.20)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: isodate>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-blob>=12.12.0->adlfs) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-blob>=12.12.0->adlfs) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-blob>=12.12.0->adlfs) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->adlfs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->adlfs) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->adlfs) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.1->azure-storage-blob>=12.12.0->adlfs) (3.2.2)
# Installing collected packages: PyJWT, portalocker, multidict, fsspec, frozenlist, async-timeout, yarl, aiosignal, aiohttp, adal, msal, azure-datalake-store, msal-extensions, azure-identity, adlfs
# Successfully installed PyJWT-2.6.0 adal-1.2.7 adlfs-2022.11.2 aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 azure-datalake-store-0.0.52 azure-identity-1.12.0 frozenlist-1.3.3 fsspec-2022.11.0 msal-1.20.0 msal-extensions-1.0.0 multidict-6.0.4 portalocker-2.6.0 yarl-1.8.2
# Requirement already satisfied: fsspec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9a6cec9a-183d-445c-a7eb-4582583d0ff8/lib/python3.9/site-packages (2022.11.0)

# %% [markdown]
# #### 2. Importing the required python packages

# %%
from datetime import datetime
import os
import sys
import time
import pickle

import numpy as np
import pandas as pd
import json
import traceback
import ast

from sherlock.functional import extract_features_to_csv
from sherlock.helpers import download_data
from sherlock.features.paragraph_vectors import initialise_pretrained_model, initialise_nltk
from sherlock.features.preprocessing import (extract_features,convert_string_lists_to_lists,prepare_feature_extraction,load_parquet_values)
from sherlock.features.word_embeddings import initialise_word_embeddings

# %% [markdown]
# #### 3. Loading the required model objects for the feature creation

# %%
par_vec_path = '/dbfs/'

# prepare_feature_extraction()
initialise_word_embeddings()
initialise_pretrained_model(path=par_vec_path,dim=400)
initialise_nltk()
# Out:
# Initialising word embeddings
# Initialise Word Embeddings process took 0:00:06.227651 seconds.
# Initialise Doc2Vec Model, 400 dim, process took 0:00:05.764275 seconds. (filename = /dbfs//par_vec_trained_model_400.pkl)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Initialised NLTK, process took 0:00:01.414576 seconds.

# %% [markdown]
# #### 4. Connecting to the ADLS for reading all the files for feature creation

# %%
import os, uuid, sys
from azure.storage.filedatalake import DataLakeServiceClient
from azure.core._match_conditions import MatchConditions
from azure.storage.filedatalake._models import ContentSettings
from azure.storage.blob import BlobServiceClient

# %%
def initialize_storage_account(storage_account_name, storage_account_key):
    
    try:  
        global service_client

        service_client = DataLakeServiceClient(account_url="{}://{}.dfs.core.windows.net".format(
            "https", storage_account_name), credential=storage_account_key)
    
    except Exception as e:
        print(e)

# %%
def list_directory_contents(container_name,my_dir):
    file_list = []
    try:
        
        file_system_client = service_client.get_file_system_client(file_system=container_name)

        paths = file_system_client.get_paths(path=my_dir)

        for path in paths:
            file_list.append(path.name)

    except Exception as e:
     print(e)
    
    return file_list

# %% [markdown]
# #### 5. Credentials to connect to the Azure Data Storage

# %%
storage_account = "legoaistorage"
storage_account_key = "vOHAjE9vOHaxqmTRxIYETQbYlPvvFpJQ7xfky8tuWBRE9E6IbfM87ERkGcqqiHfMHs+WnEt907r6+AStjIYXlA=="
initialize_storage_account(storage_account,storage_account_key)

# %%
### Spark Configuration
spark.conf.set("fs.azure.account.key."+ storage_account +".dfs.core.windows.net", storage_account_key)
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %% [markdown]
# #### 6. Parsing and extracting file information

# %%
### Getting the data and other required information from each source
container_name = 'datascience-dataset'
data_content = list_directory_contents(container_name,'Source_Data')
connect_str = 'DefaultEndpointsProtocol=https;AccountName={};AccountKey={}'.format(storage_account,storage_account_key)

# %% [markdown]
# #### 7. Iterating through the data and get all the required jsons file info

# %%
### Subset data which is of json file format
json_data_content = [content for content in data_content if content.endswith('.json')]

json_meta = []
for cont in json_data_content:
    json_meta.append([cont.split('/')[1],cont.split('/')[-1],cont])
    
json_meta_df =  pd.DataFrame(json_meta,columns= ['source','filename','filepath'])
json_meta_df = json_meta_df.reset_index(drop=True)

# %%
json_meta_df = json_meta_df[(json_meta_df['source']=='dipanjan')].reset_index(drop=True)
json_meta_df = json_meta_df[json_meta_df['filepath'].str.contains('large')].reset_index(drop=True)
json_meta_df.shape
# Out:
# Out[21]: (145, 3)

# %%
def data_conversion(filename,filepath):
    
    ## Identify the file extension
    file_extension = filename.rsplit('.',1)[1]
    full_filepath = "abfss://datascience-dataset@legoaistorage.dfs.core.windows.net/"+filepath
    
    ## Read the data based on extension
    if file_extension == 'json':
        data_dict = spark.read.option("multiline", "true").json(full_filepath)
        data = data_dict.toPandas()

    elif file_extension == 'parquet':
        data = spark.read.parquet(full_filepath)
            
    elif file_extension == 'csv':
        data = spark.read.format("csv").option("mode", "PERMISSIVE").load(full_filepath)
        
    elif file_extension == 'txt':
        data = spark.read.text(full_filepath)
    
    else:
        data = pd.DataFrame(columns=['id','table_name','column_name','values']) 
    
    return data

# %%
def meta_information_check(data_df,filename):

    ### ID creation for each df
    if 'id' in data_df.columns:
        
        if data_df['id'].nunique() != data_df.shape[0]:
            data_df['id'] = [i for i in range(len(data_df))]        
            
    elif 'column_id' in data_df.columns:
        data_df['id'] = data_df['column_id']
    else:
        data_df = data_df.reset_index(drop=True).reset_index()
        data_df = data_df.rename(columns={'index':'id'})
    
    #### Mandatory column checks
    if 'column_name' not in data_df.columns:
        
        if 'type' in data_df.columns:
            data_df['column_name'] = data_df['type']
        else:
            data_df['column_name'] = ''   ### Need to check with             
    
    if 'table_name' not in data_df.columns:
        data_df['table_name'] = filename.rsplit('.',1)[0]
    
    data_df = data_df.rename(columns={'column_values':'values','value':'values'})
    
    data_df['values'] = data_df.apply(lambda x: list(x['values']),axis=1)
    print('Unique Type of values:', list(set([type(val) for val in data_df['values'].tolist()])))
    
    assert list(set([type(val) for val in data_df['values'].tolist()]))[0] == list
    
    data_df['master_id'] = data_df.apply(lambda x: x['dataset_name']+'$$##$$'+x['table_name']+'$$##$$'+x['column_name'],axis=1)    
    assert data_df['master_id'].nunique()==data_df.shape[0]

    return data_df

# %% [markdown]
# #### 8. Storing the Information to Azure Blob Storage

# %%
### Blob storage based configurations
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client('datascience-dataset/Features')

# %%
def save_df_to_blob(df,output_file):

    try:
        output = df.to_csv(index=False, encoding = "utf-8")
        
        # Instantiate a new BlobClient
        blob_client = container_client.get_blob_client(output_file)
        
        # upload data
        blob_client.upload_blob(output, blob_type="BlockBlob")
        
        return 1
    
    except:
        return 0

# %%
for row in range(len(json_meta_df)): 
    
    status = 0
    try:
        
        print('Feature Creation Started!!')
        ## Required variables
        filename,filepath = json_meta_df[['filename','filepath']].iloc[row].tolist()

        ### Extracting data from json    
        json_df = data_conversion(filename,filepath)

        if json_df.shape[0] ==0:
            continue
        
        ### Extracting meta data    
        meta_json_df = meta_information_check(json_df,filename)
        print('Meta Data Row Count: ',meta_json_df.shape)
        
        ### Extracting features from data
        df = extract_features_to_csv(meta_json_df)
        
        ### Saving the output to the folder
        full_filepath = filename.replace('.json','.csv').replace('.parquet','.csv').replace('.xlsx','.csv').replace('.txt','.csv').replace('.csv','_feats.csv')
        
        status = save_df_to_blob(df,full_filepath) 
        
    except Exception as e:
        print(traceback.format_exc())
        print(e)

    print('Feature Creation Completed!!')
    print(row,status)

# %% [markdown]
# #### 9. Iterating through the data and combine features

# %%
### Getting the data and other required information from each source
container_name = 'datascience-dataset'
data_content = list_directory_contents(container_name,'Features')

# %%
features_df = pd.DataFrame()
for i,filename in enumerate(data_content):
    full_filepath = "abfss://datascience-dataset@legoaistorage.dfs.core.windows.net/"+filename
    feats_csv = spark.read.format("csv").option("header","true").load(full_filepath)
    feats_pandas = feats_csv.toPandas()
    feats_pandas['file_name'] = filename.split('/')[1].replace('.csv','')
    features_df = pd.concat([features_df,feats_pandas])
    print(len(data_content)-i)

# %%
### Blob storage based configurations
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client('datascience-dataset/Model_Data')
filepath = "model_feats_data.csv"
save_df_to_blob(features_df,filepath)

# %% [markdown]
# #### 10. Evaluating Execution Performance

# %%
features_df['execution_time'] = pd.to_timedelta(features_df['execution_time'])
features_df = features_df.reset_index(drop=True)
features_df['execution_seconds'] = features_df['execution_time']/np.timedelta64(1, 's')

# %%
new_features_df = features_df[['repo_name','file_name','execution_time','execution_seconds']].drop_duplicates().reset_index()
new_features_df = new_features_df.drop(columns=['index'])

# %%
### Blob storage based configurations
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client('datascience-dataset/Model_Data')
filepath = "feature_execution_data.csv"
save_df_to_blob(new_features_df,filepath)

# %%
### Getting the data and other required information from each source
container_name = 'datascience-dataset'
data_content = list_directory_contents(container_name,'Source_Data')
all_files = pd.DataFrame([file.split('/')[-1].replace('.json','_feats') for file in data_content if file.endswith('.json')],columns=['file_name'])

# %%
merged_df = pd.merge(all_files,features_df[['repo_name','file_name']],how='left')
merged_df[pd.isnull(merged_df['repo_name'])]['file_name'].tolist()

# %% [markdown]
# #### Appendix

# %%
import nltk
from nltk.corpus import stopwords
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

STOPWORDS_ENGLISH = stopwords.words("english")

def tokenise(values):
    joined = " ".join(s for s in values if len(s) >= 1)

    # stopwords need apostrophe
    filtered = "".join(
        e for e in joined if e.isalnum() or e.isspace() or e == "'"
    ).lower()

    return [
        word
        for word in nltk.word_tokenize(filtered)
        if len(word) >= 1 and word not in STOPWORDS_ENGLISH
    ]

# %%
filename = f"/dbfs/par_vec_trained_model_400.pkl"        
model = Doc2Vec.load(filename)

# %%
model.random.seed(13)
col_values = meta_json_df[meta_json_df['id']=='nov2019_deliveries_wide_runs_11']['values'].tolist()[0]
tokens = tokenise(col_values)
inferred = model.infer_vector(tokens, steps=20, alpha=0.025)

# %%
def alphaAndNumericMatch(value):
    
    value = str(value)
    charCount = len(re.findall(string = value,pattern='[a-zA-Z]'))
    numCount = len(re.findall(string = value,pattern='\d'))
    specialCharCount = len(re.findall(string=value,pattern='[!#&\'()*+-/:;<=>?@[\\]^_`{|}~]'))

    if (charCount >0 or specialCharCount) and numCount>0:
        return 'alphanumeric'
    elif numCount > 0:
        return 'numeric'
    elif charCount > 0:
        return 'alpha'
    else:
        return 'others'
